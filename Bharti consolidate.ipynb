# %%
import pandas as pd
# import Workbook
from openpyxl import Workbook

# %%
df1= pd.read_excel('/Users/sanjeevkumar/Desktop/Python/Excel sheet consolidation/400KV-BAY-401.xls', sheet_name = None)

# %%
df1
# Out:
# {'Page 1':               1                                         Unnamed: 1  \
#  0   \n\n\n\n\nA  \n\n\n\n\n\n\n\n\n\nHYOSUNG T&D INDIA PVT. LTD...
#  1   \n\n\n\n\nB                                                NaN
#  2           NaN                                                NaN
#  3   \n\n\n\n\nC                                                NaN
#  4           NaN                                                NaN
#  5   \n\n\n\n\nD                                                NaN
#  6           NaN                                                NaN
#  7           NaN                                                NaN
#  8   \n\n\n\n\nE                                                NaN
#  9         \n\nF                                                NaN
#  10         REV.                                                NaN
#  11           01                                                NaN
#  12           02                                                NaN
# ...

# %%
df2 = pd.concat(df1[frame] for frame in df1.keys())

# %%
df2.rename( columns={'Unnamed: 3':'cable'}, inplace=True )

# %%
df2.dropna(subset = ["cable"], inplace=True)

# %%
df2.head(400)
# Out:
#        1 Unnamed: 1  Unnamed: 2                 cable   2 Unnamed: 5  \
# 10  REV.        NaN        DATE              CONTENTS NaN        NaN
# 11    01        NaN  16/11/2020  DRAWING FOR APPROVAL NaN        NaN
# 12    02        NaN  19/01/2021       AS PER COMMENTS NaN        NaN
# 1    NaN        NaN         NaN         Cable Tag No. NaN        NaN
# 3    NaN        NaN         NaN      \nCABLE CORE NO. NaN        NaN
# ..   ...        ...         ...                   ...  ..        ...
# 19   NaN        NaN         NaN                    13 NaN        NaN
# 21   NaN        NaN         NaN                    14 NaN        NaN
# 22   NaN        NaN         NaN                    15 NaN        NaN
# 23   NaN        NaN         NaN                    16 NaN        NaN
# 1    NaN        NaN         NaN         Cable Tag No. NaN        NaN
#
#       Unnamed: 6 Unnamed: 7    Unnamed: 8   3  ... Unnamed: 29  \
# 10      DRAWN BY        NaN    CHECKED BY NaN  ...         NaN
# ...

# %%
df3 = df2.iloc[4: , :]

# %% [markdown]
# ###

# %%
df4 = df3.iloc[:,3:]

# %%
df_new = df4[['cable','Unnamed: 6','Unnamed: 16','Unnamed: 22','Unnamed: 6','Unnamed: 26','Unnamed: 27']]

# %%
df_new.dropna(subset = ["Unnamed: 22"], inplace=True)
# Out:
# <ipython-input-82-dd5afbcb83ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.dropna(subset = ["Unnamed: 22"], inplace=True)

# %%
df_new
# Out:
#    cable             Unnamed: 6 Unnamed: 16 Unnamed: 22  \
# 6      1          +401-52-R-MX1         -X1           5
# 7      2          +401-52-R-MX1         -X1           6
# 8      3          +401-52-R-MX1         -X1           7
# 9      4          +401-52-R-MX1         -X1           8
# 10     5          +401-52-R-MX1         -X1           9
# ..   ...                    ...         ...         ...
# 9      4  +401-CTA-CTA-CT5:Y-PH    -XCT-BB1          66
# 6      1  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          67
# 7      2  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          68
# 8      3  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          69
# 9      4  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          70
#
#                Unnamed: 6 Unnamed: 26 Unnamed: 27
# 6           +401-52-R-MX1       /83.0        K41R
# 7           +401-52-R-MX1       /83.0         K54
# 8           +401-52-R-MX1       /83.1        K33R
# 9           +401-52-R-MX1       /83.1        K43R
# ...

# %%
df_new.loc[len(df)] = 0
# Out:
# /Users/sanjeevkumar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
dfn1 = df_new.shift()

# %%
dfn1
# Out:
#    cable             Unnamed: 6 Unnamed: 16 Unnamed: 22  \
# 6    NaN                    NaN         NaN         NaN
# 7      1          +401-52-R-MX1         -X1           5
# 8      2          +401-52-R-MX1         -X1           6
# 9      3          +401-52-R-MX1         -X1           7
# 10     4          +401-52-R-MX1         -X1           8
# ..   ...                    ...         ...         ...
# 6      4  +401-CTA-CTA-CT5:Y-PH    -XCT-BB1          66
# 7      1  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          67
# 8      2  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          68
# 9      3  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          69
# 38     4  +401-CTA-CTA-CT5:B-PH    -XCT-BB1          70
#
#                Unnamed: 6 Unnamed: 26 Unnamed: 27
# 6                     NaN         NaN         NaN
# 7           +401-52-R-MX1       /83.0        K41R
# 8           +401-52-R-MX1       /83.0         K54
# 9           +401-52-R-MX1       /83.1        K33R
# ...

# %%
dfn1.iloc[0] = ['CABLE CORE NO.', 'GIS EQUIPMENT','TERMINAL TAG NO.','TERMINAL NO.','Duplicate','REF. SHEET NO.','FERRULE NO.']

# %%
dfn1
# Out:
#              cable             Unnamed: 6       Unnamed: 16   Unnamed: 22  \
# 6   CABLE CORE NO.          GIS EQUIPMENT  TERMINAL TAG NO.  TERMINAL NO.
# 7                1          +401-52-R-MX1               -X1             5
# 8                2          +401-52-R-MX1               -X1             6
# 9                3          +401-52-R-MX1               -X1             7
# 10               4          +401-52-R-MX1               -X1             8
# ..             ...                    ...               ...           ...
# 6                4  +401-CTA-CTA-CT5:Y-PH          -XCT-BB1            66
# 7                1  +401-CTA-CTA-CT5:B-PH          -XCT-BB1            67
# 8                2  +401-CTA-CTA-CT5:B-PH          -XCT-BB1            68
# 9                3  +401-CTA-CTA-CT5:B-PH          -XCT-BB1            69
# 38               4  +401-CTA-CTA-CT5:B-PH          -XCT-BB1            70
#
#                Unnamed: 6     Unnamed: 26  Unnamed: 27
# ...

# %%
dfn1.dropna(subset = ["Unnamed: 27"], inplace=True)

# %%
file_name = "/Users/sanjeevkumar/Desktop/Python/Excel sheet consolidation/test.xls"
dfn1.to_excel(file_name)
# Out:
# <ipython-input-93-e2efa51c3219>:2: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   dfn1.to_excel(file_name)
